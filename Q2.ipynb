# %% [markdown]
# # Without Metadata

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.multitest import multipletests
import statsmodels.api as sm
import statsmodels.stats.multitest as smm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing the dataset

# %%
clr_data = pd.read_excel('/content/drive/MyDrive/hmds Assignments/Assignment1_ClrTrans_Species.xlsx', index_col=0)
metadata = pd.read_excel('/content/drive/MyDrive/hmds Assignments/Assignment1_Metadata.xlsx', index_col=0)

# %% [markdown]
# ## Filter out species detected in less than 5% of the samples

# %%
detected_species = (clr_data > 0).sum(axis=1)
clr_data = clr_data.loc[detected_species[detected_species >= len(clr_data)*0.05].index]

# %%
clr_data
# Out:
#                 Bifidobacterium_dentium  Butyricimonas_synergistica  \
# AIIDB0330                      2.484907                    2.197225
# AIIDM0042                      0.000000                    0.000000
# AIIDM0318                      0.000000                    0.000000
# AIIDV1015                      0.693147                    0.000000
# AIIDV1406                      0.000000                    0.000000
# ...                                 ...                         ...
# AIIDM0040                      1.609438                    0.000000
# COVIRL-201-015                 7.774856                    0.000000
# AIIDV1085                      0.000000                    0.000000
# AIIDM0020                      0.000000                    0.000000
# COVIRL-201-035                 2.397895                    0.000000
#
#                 Parvibacter_caecicola  Clostridium_sartagoforme  \
# AIIDB0330                    0.000000                  0.000000
# AIIDM0042                    0.000000                  0.000000
# AIIDM0318                    0.000000                  0.000000
# AIIDV1015                    0.000000                  0.693147
# AIIDV1406                    0.000000                  0.000000
# ...                               ...                       ...
# AIIDM0040                    0.000000                  0.000000
# COVIRL-201-015               0.000000                  3.555348
# AIIDV1085                    0.000000                  0.000000
# AIIDM0020                    0.000000                  0.000000
# COVIRL-201-035               1.098612                  2.397895
#
#                 Ruminococcus_gauvreauii  Bacteroides_stercoris  \
# AIIDB0330                      3.332205               7.753624
# AIIDM0042                      0.000000               0.000000
# AIIDM0318                      0.000000               0.000000
# AIIDV1015                      1.609438               0.000000
# AIIDV1406                      2.564949               0.000000
# ...                                 ...                    ...
# AIIDM0040                      1.609438               0.000000
# COVIRL-201-015                 1.098612               0.000000
# AIIDV1085                      0.000000               1.386294
# AIIDM0020                      3.044522               0.000000
# COVIRL-201-035                 4.962845               0.000000
#
#                 Bacteroides_plebeius  Streptococcus_parasanguinis  \
# AIIDB0330                   0.000000                     4.442651
# AIIDM0042                   0.000000                     0.000000
# AIIDM0318                   0.000000                     0.000000
# AIIDV1015                   0.000000                     0.000000
# AIIDV1406                   0.000000                     0.000000
# ...                              ...                          ...
# AIIDM0040                   0.000000                     0.693147
# COVIRL-201-015              6.023448                     4.025352
# AIIDV1085                   0.000000                     0.000000
# AIIDM0020                   0.000000                     0.000000
# COVIRL-201-035              2.197225                     3.713572
#
#                 Enterococcus_rivorum  Clostridium_methylpentosum  ...  \
# AIIDB0330                   0.000000                    4.919981  ...
# AIIDM0042                   0.693147                    0.693147  ...
# AIIDM0318                   0.000000                    3.258097  ...
# AIIDV1015                   0.000000                    0.693147  ...
# AIIDV1406                   0.000000                    2.079442  ...
# ...                              ...                         ...  ...
# AIIDM0040                   0.000000                    0.000000  ...
# COVIRL-201-015              0.693147                    6.431331  ...
# AIIDV1085                   0.000000                    1.609438  ...
# AIIDM0020                   0.000000                    2.995732  ...
# COVIRL-201-035              0.000000                    4.890349  ...
#
#                 Anaerotruncus_colihominis  Lactobacillus_sakei  \
# AIIDB0330                        7.163947             0.000000
# AIIDM0042                        0.000000             0.000000
# AIIDM0318                        0.000000             0.000000
# AIIDV1015                        0.000000             0.000000
# AIIDV1406                        0.000000             0.000000
# ...                                   ...                  ...
# AIIDM0040                        0.000000             0.000000
# COVIRL-201-015                   5.342334             0.000000
# AIIDV1085                        1.386294             0.000000
# AIIDM0020                        2.302585             1.098612
# COVIRL-201-035                   2.397895             0.000000
#
#                 Eubacterium_xylanophilum  Slackia_isoflavoniconvertens  \
# AIIDB0330                       2.890372                      5.525453
# AIIDM0042                       0.000000                      0.000000
# AIIDM0318                       0.000000                      0.000000
# AIIDV1015                       1.791759                      3.583519
# AIIDV1406                       0.000000                      0.000000
# ...                                  ...                           ...
# AIIDM0040                       0.000000                      2.944439
# COVIRL-201-015                  0.000000                      0.000000
# AIIDV1085                       0.000000                      2.833213
# AIIDM0020                       0.000000                      0.000000
# COVIRL-201-035                  0.693147                      1.098612
#
#                 Alistipes_massiliensis  Veillonella_atypica  \
# AIIDB0330                     5.170484             1.098612
# AIIDM0042                     0.000000             0.000000
# AIIDM0318                     0.693147             3.761200
# AIIDV1015                     0.693147             0.000000
# AIIDV1406                     0.000000             0.000000
# ...                                ...                  ...
# AIIDM0040                     0.000000             2.833213
# COVIRL-201-015                0.000000             0.000000
# AIIDV1085                     0.000000             0.000000
# AIIDM0020                     0.000000             0.000000
# COVIRL-201-035                0.693147             0.000000
#
#                 Enterococcus_casseliflavus  Olsenella_profusa  \
# AIIDB0330                         0.000000           1.609438
# AIIDM0042                         0.000000           0.000000
# AIIDM0318                         0.000000           0.000000
# AIIDV1015                         0.000000           0.693147
# AIIDV1406                         0.000000           0.000000
# ...                                    ...                ...
# AIIDM0040                         0.000000           0.000000
# COVIRL-201-015                    2.197225           0.000000
# AIIDV1085                         0.000000           0.693147
# AIIDM0020                         0.000000           0.000000
# COVIRL-201-035                    0.000000           0.000000
#
#                 Lactobacillus_reuteri  Peptococcus_niger
# AIIDB0330                    4.418841           0.000000
# AIIDM0042                    0.000000           0.000000
# AIIDM0318                    0.000000           0.000000
# AIIDV1015                    0.000000           0.000000
# AIIDV1406                    0.000000           0.000000
# ...                               ...                ...
# AIIDM0040                    0.000000           0.000000
# COVIRL-201-015               0.000000           0.000000
# AIIDV1085                    0.000000           4.779123
# AIIDM0020                    0.000000           0.000000
# COVIRL-201-035               0.000000           0.000000
#
# [82 rows x 275 columns]

# %% [markdown]
# ## Convert Covid-19 severity and Gender to numeric encoding

# %%
severity_mapping = {'mild': 1, 'moderate': 2, 'critical_severe': 3}
gender_mapping = {'F':0,'M':1}
metadata['WHO_severity'] = metadata['WHO_severity'].map(severity_mapping)
metadata['Sex'] = metadata['Sex'].map(gender_mapping)

# %%
metadata
# Out:
#                 Sex  Age        BMI HTN Diabetes Respiratory_disease  \
# AIIDB0330         1   63  48.995023   n        y                   n
# AIIDM0042         1   63  30.322325   y        n                   n
# AIIDM0318         1   41  30.322325   n        n                   n
# AIIDV1015         0   42  57.795561   n        n                   n
# AIIDV1406         0   85  23.728191   y        y                   y
# ...             ...  ...        ...  ..      ...                 ...
# AIIDM0040         0   43  30.322325   n        n                   n
# COVIRL-201-015    0   87  25.562130   n        n                   y
# AIIDV1085         1   78  26.543210   n        y                   n
# AIIDM0020         1   74  30.322325   y        n                   n
# COVIRL-201-035    1   38  24.228395   n        n                   n
#
#                Heart_disease Renal_Disease Liver_Disease Obesity Malignancy  \
# AIIDB0330                  y             y             n       y          n
# AIIDM0042                  n             n             n       n          n
# AIIDM0318                  n             n             n       n          n
# AIIDV1015                  n             n             n       y          n
# AIIDV1406                  y             y             n       n          y
# ...                      ...           ...           ...     ...        ...
# AIIDM0040                  n             n             n       n          n
# COVIRL-201-015             y             n             n       n          n
# AIIDV1085                  y             n             n       n          y
# AIIDM0020                  y             n             n       n          n
# COVIRL-201-035             n             n             n       n          n
#
#                Immunosuppressive_Disease Neurological_disease  \
# AIIDB0330                              n                    n
# AIIDM0042                              n                    n
# AIIDM0318                              n                    n
# AIIDV1015                              n                    n
# AIIDV1406                              n                    n
# ...                                  ...                  ...
# AIIDM0040                              n                    n
# COVIRL-201-015                         n                    n
# AIIDV1085                              n                    n
# AIIDM0020                              n                    n
# COVIRL-201-035                         n                    n
#
#                Metabolic_Disease Cardiovascular_Disease  comorbidities_total  \
# AIIDB0330                      y                      y                    6
# AIIDM0042                      y                      y                    3
# AIIDM0318                      n                      n                    0
# AIIDV1015                      y                      n                    2
# AIIDV1406                      y                      y                    8
# ...                          ...                    ...                  ...
# AIIDM0040                      n                      n                    0
# COVIRL-201-015                 n                      y                    3
# AIIDV1085                      y                      y                    5
# AIIDM0020                      y                      y                    4
# COVIRL-201-035                 n                      n                    0
#
#                 WHO_severity
# AIIDB0330                  3
# AIIDM0042                  2
# AIIDM0318                  3
# AIIDV1015                  1
# AIIDV1406                  1
# ...                      ...
# AIIDM0040                  2
# COVIRL-201-015             3
# AIIDV1085                  3
# AIIDM0020                  1
# COVIRL-201-035             3
#
# [82 rows x 17 columns]

# %% [markdown]
# ## Perform linear regression for each species

# %%
results = []
for species in clr_data.columns:
    x = clr_data[species]
    y = metadata['WHO_severity']
    model = sm.OLS(y, sm.add_constant(x)).fit()
    results.append((species, model.pvalues[1]))

# %% [markdown]
# ## Correct for multiple testing using the Benjamini-Hochberg method

# %%
p_values = [i[1] for i in results]
reject, pvalues, _, _ = multipletests(p_values, method='fdr_bh')

# extract the significant species
sig_species = [r[0] for i, r in enumerate(results) if pvalues[i] <= 0.1]

# %% [markdown]
# ## Significant species

# %%
# Print significant species
print('Significant species after adjustment (FDR <= 0.1):', len(sig_species))
# Out:
# Significant species after adjustment (FDR <= 0.1): 83

# %%
[(r[0],r[1]) for i, r in enumerate(results) if pvalues[i] <= 0.1]
# Out:
# [('Clostridium_sartagoforme', 0.001814317037460714),
#  ('Bacteroides_plebeius', 0.0025090452648332882),
#  ('Clostridium_methylpentosum', 0.0003101867914927888),
#  ('Escherichia.Shigella_flexneri', 0.030099378162692807),
#  ('Subdoligranulum_variabile', 0.011951201287901413),
#  ('Clostridium_disporicum', 0.0003706793559823975),
#  ('Finegoldia_magna', 0.0016203824930970496),
#  ('Bacteroides_acidifaciens', 0.00015912151855799437),
#  ('Atopobium_parvulum', 0.006632599675692202),
#  ('Blautia_schinkii', 0.007120391799397053),
#  ('Clostridium_aminobutyricum', 0.01050132855846613),
#  ('Enterococcus_mundtii', 0.011026385161287353),
#  ('Anaerostipes_butyraticus', 0.009269569552335741),
#  ('Acidaminococcus_intestini', 0.01645526176783011),
#  ('Methanobrevibacter_smithii', 4.0535270913807776e-05),
#  ('Eubacterium_siraeum', 0.01510024826869974),
#  ('Solobacterium_moorei', 0.0012923564702762627),
#  ('Anaerosporobacter_mobilis', 0.006673868521490599),
#  ('Blautia_stercoris', 0.008097619254980874),
#  ('Melissococcus_plutonius', 0.004987674030320956),
#  ('Clostridium_bifermentans', 0.012510784072456028),
#  ('Christensenella_minuta', 0.018671248607039042),
#  ('Streptococcus_sanguinis', 0.003845587774184804),
#  ('Actinomyces_graevenitzii', 0.012450229713108973),
#  ('Pseudoflavonifractor_capillosus', 0.0003001001665682188),
#  ('Coprobacillus_cateniformis', 0.012737847223253591),
#  ('Lactobacillus_fermentum', 0.009996763250810338),
#  ('Clostridium_viride', 0.015230815434657693),
#  ('Eubacterium_contortum', 2.7994060605946616e-05),
#  ('Actinomyces_odontolyticus', 0.013400331224940224),
#  ('Actinomyces_lingnae', 0.017010445309338155),
#  ('Clostridium_irregulare', 0.00019740717705326612),
#  ('Acetanaerobacterium_elongatum', 0.02305031605223211),
#  ('Clostridium_aldenense', 0.002359551727761985),
#  ('Blautia_luti', 0.009634288362630196),
#  ('Bacteroides_ovatus', 0.012889060601413887),
#  ('Anaerofilum_pentosovorans', 0.022425098370764823),
#  ('Clostridium_tertium', 0.014730763409839906),
#  ('Papillibacter_cinnamivorans', 0.029385285299540223),
#  ('Clostridium_lavalense', 0.0009915439981034169),
#  ('Clostridium_cellulosi', 0.004879012477323349),
#  ('Bacteroides_nordii', 0.020229692469636084),
#  ('Actinomyces_naeslundii', 0.0002584821618147399),
#  ('Clostridium_oroticum', 0.0042111559455797025),
#  ('Eubacterium_oxidoreducens', 0.02065299411695143),
#  ('Anaerorhabdus_furcosa', 0.00016510337966346174),
#  ('Clostridium_leptum', 0.0073407229626938405),
#  ('Holdemania_filiformis', 0.011618102469843839),
#  ('Alistipes_finegoldii', 0.001266636717745596),
#  ('Hydrogenoanaerobacterium_saccharovorans', 0.006997545702331115),
#  ('Clostridium_innocuum', 1.4002637227923701e-05),
#  ('Enterococcus_hirae', 0.026685074559039967),
#  ('Blautia_wexlerae', 0.021817423755102254),
#  ('Acetivibrio_ethanolgignens', 0.002614948222464524),
#  ('Eubacterium_ventriosum', 0.010761650764491596),
#  ('Enterococcus_asini', 0.008943950111934594),
#  ('Clostridium_thermocellum', 0.01346394104182221),
#  ('Clostridium_hathewayi', 0.0006946725441064212),
#  ('Clostridium_citroniae', 0.0023061237381931106),
#  ('Lactonifactor_longoviformis', 0.004748362814726725),
#  ('Dialister_invisus', 0.000995954823118133),
#  ('Saccharofermentans_acetigenes', 0.029072895269843472),
#  ('Hespellia_porcina', 0.00026608413331911327),
#  ('Ruminococcus_obeum', 0.013677179815559923),
#  ('Actinomyces_massiliensis', 0.010902370037146617),
#  ('Faecalibacterium_prausnitzii', 0.02927174352502551),
#  ('Marvinbryantia_formatexigens', 0.007226605320160721),
#  ('Clostridium_clostridioforme', 3.732316184359633e-05),
#  ('Ruminococcus_lactaris', 0.0016449998778516079),
#  ('Clostridium_asparagiforme', 0.01874242984157092),
#  ('Enterococcus_faecalis', 0.006277110336891976),
#  ('Eggerthella_lenta', 0.0003415493315232234),
#  ('Clostridium_hiranonis', 0.0036693451210623347),
#  ('Anaerofustis_stercorihominis', 0.01773775608168543),
#  ('Oribacterium_sinus', 0.01433769228153853),
#  ('Clostridium_sporosphaeroides', 0.002894993252377775),
#  ('Clostridium_symbiosum', 0.027859412936158085),
#  ('Eubacterium_coprostanoligenes', 0.023956254091312395),
#  ('Butyrivibrio_fibrisolvens', 0.0031697676407803177),
#  ('Natranaerovirga_pectinivora', 0.008283618269044979),
#  ('Robinsoniella_peoriensis', 0.0026494680183904076),
#  ('Enterococcus_casseliflavus', 0.004721914831589958),
#  ('Peptococcus_niger', 0.02933100438397556)]

# %%
sig_species
# Out:
# ['Clostridium_sartagoforme',
#  'Bacteroides_plebeius',
#  'Clostridium_methylpentosum',
#  'Escherichia.Shigella_flexneri',
#  'Subdoligranulum_variabile',
#  'Clostridium_disporicum',
#  'Finegoldia_magna',
#  'Bacteroides_acidifaciens',
#  'Atopobium_parvulum',
#  'Blautia_schinkii',
#  'Clostridium_aminobutyricum',
#  'Enterococcus_mundtii',
#  'Anaerostipes_butyraticus',
#  'Acidaminococcus_intestini',
#  'Methanobrevibacter_smithii',
#  'Eubacterium_siraeum',
#  'Solobacterium_moorei',
#  'Anaerosporobacter_mobilis',
#  'Blautia_stercoris',
#  'Melissococcus_plutonius',
#  'Clostridium_bifermentans',
#  'Christensenella_minuta',
#  'Streptococcus_sanguinis',
#  'Actinomyces_graevenitzii',
#  'Pseudoflavonifractor_capillosus',
#  'Coprobacillus_cateniformis',
#  'Lactobacillus_fermentum',
#  'Clostridium_viride',
#  'Eubacterium_contortum',
#  'Actinomyces_odontolyticus',
#  'Actinomyces_lingnae',
#  'Clostridium_irregulare',
#  'Acetanaerobacterium_elongatum',
#  'Clostridium_aldenense',
#  'Blautia_luti',
#  'Bacteroides_ovatus',
#  'Anaerofilum_pentosovorans',
#  'Clostridium_tertium',
#  'Papillibacter_cinnamivorans',
#  'Clostridium_lavalense',
#  'Clostridium_cellulosi',
#  'Bacteroides_nordii',
#  'Actinomyces_naeslundii',
#  'Clostridium_oroticum',
#  'Eubacterium_oxidoreducens',
#  'Anaerorhabdus_furcosa',
#  'Clostridium_leptum',
#  'Holdemania_filiformis',
#  'Alistipes_finegoldii',
#  'Hydrogenoanaerobacterium_saccharovorans',
#  'Clostridium_innocuum',
#  'Enterococcus_hirae',
#  'Blautia_wexlerae',
#  'Acetivibrio_ethanolgignens',
#  'Eubacterium_ventriosum',
#  'Enterococcus_asini',
#  'Clostridium_thermocellum',
#  'Clostridium_hathewayi',
#  'Clostridium_citroniae',
#  'Lactonifactor_longoviformis',
#  'Dialister_invisus',
#  'Saccharofermentans_acetigenes',
#  'Hespellia_porcina',
#  'Ruminococcus_obeum',
#  'Actinomyces_massiliensis',
#  'Faecalibacterium_prausnitzii',
#  'Marvinbryantia_formatexigens',
#  'Clostridium_clostridioforme',
#  'Ruminococcus_lactaris',
#  'Clostridium_asparagiforme',
#  'Enterococcus_faecalis',
#  'Eggerthella_lenta',
#  'Clostridium_hiranonis',
#  'Anaerofustis_stercorihominis',
#  'Oribacterium_sinus',
#  'Clostridium_sporosphaeroides',
#  'Clostridium_symbiosum',
#  'Eubacterium_coprostanoligenes',
#  'Butyrivibrio_fibrisolvens',
#  'Natranaerovirga_pectinivora',
#  'Robinsoniella_peoriensis',
#  'Enterococcus_casseliflavus',
#  'Peptococcus_niger']

# %% [markdown]
# # With Including Metadata

# %% [markdown]
# ## Importing the dataset

# %%
clr_data_df = pd.read_excel('/content/drive/MyDrive/hmds Assignments/Assignment1_ClrTrans_Species.xlsx', index_col=0)
metadata_df = pd.read_excel('/content/drive/MyDrive/hmds Assignments/Assignment1_Metadata.xlsx', index_col=0)

# %% [markdown]
# ## Filter out species detected in less than 5% of the samples

# %%
detected_species = (clr_data_df > 0).sum(axis=1)
clr_data_df = clr_data_df.loc[detected_species[detected_species >= len(clr_data_df)*0.05].index]

# %%
clr_data_df
# Out:
#                 Bifidobacterium_dentium  Butyricimonas_synergistica  \
# AIIDB0330                      2.484907                    2.197225
# AIIDM0042                      0.000000                    0.000000
# AIIDM0318                      0.000000                    0.000000
# AIIDV1015                      0.693147                    0.000000
# AIIDV1406                      0.000000                    0.000000
# ...                                 ...                         ...
# AIIDM0040                      1.609438                    0.000000
# COVIRL-201-015                 7.774856                    0.000000
# AIIDV1085                      0.000000                    0.000000
# AIIDM0020                      0.000000                    0.000000
# COVIRL-201-035                 2.397895                    0.000000
#
#                 Parvibacter_caecicola  Clostridium_sartagoforme  \
# AIIDB0330                    0.000000                  0.000000
# AIIDM0042                    0.000000                  0.000000
# AIIDM0318                    0.000000                  0.000000
# AIIDV1015                    0.000000                  0.693147
# AIIDV1406                    0.000000                  0.000000
# ...                               ...                       ...
# AIIDM0040                    0.000000                  0.000000
# COVIRL-201-015               0.000000                  3.555348
# AIIDV1085                    0.000000                  0.000000
# AIIDM0020                    0.000000                  0.000000
# COVIRL-201-035               1.098612                  2.397895
#
#                 Ruminococcus_gauvreauii  Bacteroides_stercoris  \
# AIIDB0330                      3.332205               7.753624
# AIIDM0042                      0.000000               0.000000
# AIIDM0318                      0.000000               0.000000
# AIIDV1015                      1.609438               0.000000
# AIIDV1406                      2.564949               0.000000
# ...                                 ...                    ...
# AIIDM0040                      1.609438               0.000000
# COVIRL-201-015                 1.098612               0.000000
# AIIDV1085                      0.000000               1.386294
# AIIDM0020                      3.044522               0.000000
# COVIRL-201-035                 4.962845               0.000000
#
#                 Bacteroides_plebeius  Streptococcus_parasanguinis  \
# AIIDB0330                   0.000000                     4.442651
# AIIDM0042                   0.000000                     0.000000
# AIIDM0318                   0.000000                     0.000000
# AIIDV1015                   0.000000                     0.000000
# AIIDV1406                   0.000000                     0.000000
# ...                              ...                          ...
# AIIDM0040                   0.000000                     0.693147
# COVIRL-201-015              6.023448                     4.025352
# AIIDV1085                   0.000000                     0.000000
# AIIDM0020                   0.000000                     0.000000
# COVIRL-201-035              2.197225                     3.713572
#
#                 Enterococcus_rivorum  Clostridium_methylpentosum  ...  \
# AIIDB0330                   0.000000                    4.919981  ...
# AIIDM0042                   0.693147                    0.693147  ...
# AIIDM0318                   0.000000                    3.258097  ...
# AIIDV1015                   0.000000                    0.693147  ...
# AIIDV1406                   0.000000                    2.079442  ...
# ...                              ...                         ...  ...
# AIIDM0040                   0.000000                    0.000000  ...
# COVIRL-201-015              0.693147                    6.431331  ...
# AIIDV1085                   0.000000                    1.609438  ...
# AIIDM0020                   0.000000                    2.995732  ...
# COVIRL-201-035              0.000000                    4.890349  ...
#
#                 Anaerotruncus_colihominis  Lactobacillus_sakei  \
# AIIDB0330                        7.163947             0.000000
# AIIDM0042                        0.000000             0.000000
# AIIDM0318                        0.000000             0.000000
# AIIDV1015                        0.000000             0.000000
# AIIDV1406                        0.000000             0.000000
# ...                                   ...                  ...
# AIIDM0040                        0.000000             0.000000
# COVIRL-201-015                   5.342334             0.000000
# AIIDV1085                        1.386294             0.000000
# AIIDM0020                        2.302585             1.098612
# COVIRL-201-035                   2.397895             0.000000
#
#                 Eubacterium_xylanophilum  Slackia_isoflavoniconvertens  \
# AIIDB0330                       2.890372                      5.525453
# AIIDM0042                       0.000000                      0.000000
# AIIDM0318                       0.000000                      0.000000
# AIIDV1015                       1.791759                      3.583519
# AIIDV1406                       0.000000                      0.000000
# ...                                  ...                           ...
# AIIDM0040                       0.000000                      2.944439
# COVIRL-201-015                  0.000000                      0.000000
# AIIDV1085                       0.000000                      2.833213
# AIIDM0020                       0.000000                      0.000000
# COVIRL-201-035                  0.693147                      1.098612
#
#                 Alistipes_massiliensis  Veillonella_atypica  \
# AIIDB0330                     5.170484             1.098612
# AIIDM0042                     0.000000             0.000000
# AIIDM0318                     0.693147             3.761200
# AIIDV1015                     0.693147             0.000000
# AIIDV1406                     0.000000             0.000000
# ...                                ...                  ...
# AIIDM0040                     0.000000             2.833213
# COVIRL-201-015                0.000000             0.000000
# AIIDV1085                     0.000000             0.000000
# AIIDM0020                     0.000000             0.000000
# COVIRL-201-035                0.693147             0.000000
#
#                 Enterococcus_casseliflavus  Olsenella_profusa  \
# AIIDB0330                         0.000000           1.609438
# AIIDM0042                         0.000000           0.000000
# AIIDM0318                         0.000000           0.000000
# AIIDV1015                         0.000000           0.693147
# AIIDV1406                         0.000000           0.000000
# ...                                    ...                ...
# AIIDM0040                         0.000000           0.000000
# COVIRL-201-015                    2.197225           0.000000
# AIIDV1085                         0.000000           0.693147
# AIIDM0020                         0.000000           0.000000
# COVIRL-201-035                    0.000000           0.000000
#
#                 Lactobacillus_reuteri  Peptococcus_niger
# AIIDB0330                    4.418841           0.000000
# AIIDM0042                    0.000000           0.000000
# AIIDM0318                    0.000000           0.000000
# AIIDV1015                    0.000000           0.000000
# AIIDV1406                    0.000000           0.000000
# ...                               ...                ...
# AIIDM0040                    0.000000           0.000000
# COVIRL-201-015               0.000000           0.000000
# AIIDV1085                    0.000000           4.779123
# AIIDM0020                    0.000000           0.000000
# COVIRL-201-035               0.000000           0.000000
#
# [82 rows x 275 columns]

# %% [markdown]
# ## Convert Covid-19 severity and Gender to numeric encoding

# %%
severity_mapping = {'mild': 1, 'moderate': 2, 'critical_severe': 3}
gender_mapping = {'F':0,'M':1}
metadata_df['WHO_severity'] = metadata_df['WHO_severity'].map(severity_mapping)
metadata_df['Sex'] = metadata_df['Sex'].map(gender_mapping)

# %%
metadata_df
# Out:
#                 Sex  Age        BMI HTN Diabetes Respiratory_disease  \
# AIIDB0330         1   63  48.995023   n        y                   n
# AIIDM0042         1   63  30.322325   y        n                   n
# AIIDM0318         1   41  30.322325   n        n                   n
# AIIDV1015         0   42  57.795561   n        n                   n
# AIIDV1406         0   85  23.728191   y        y                   y
# ...             ...  ...        ...  ..      ...                 ...
# AIIDM0040         0   43  30.322325   n        n                   n
# COVIRL-201-015    0   87  25.562130   n        n                   y
# AIIDV1085         1   78  26.543210   n        y                   n
# AIIDM0020         1   74  30.322325   y        n                   n
# COVIRL-201-035    1   38  24.228395   n        n                   n
#
#                Heart_disease Renal_Disease Liver_Disease Obesity Malignancy  \
# AIIDB0330                  y             y             n       y          n
# AIIDM0042                  n             n             n       n          n
# AIIDM0318                  n             n             n       n          n
# AIIDV1015                  n             n             n       y          n
# AIIDV1406                  y             y             n       n          y
# ...                      ...           ...           ...     ...        ...
# AIIDM0040                  n             n             n       n          n
# COVIRL-201-015             y             n             n       n          n
# AIIDV1085                  y             n             n       n          y
# AIIDM0020                  y             n             n       n          n
# COVIRL-201-035             n             n             n       n          n
#
#                Immunosuppressive_Disease Neurological_disease  \
# AIIDB0330                              n                    n
# AIIDM0042                              n                    n
# AIIDM0318                              n                    n
# AIIDV1015                              n                    n
# AIIDV1406                              n                    n
# ...                                  ...                  ...
# AIIDM0040                              n                    n
# COVIRL-201-015                         n                    n
# AIIDV1085                              n                    n
# AIIDM0020                              n                    n
# COVIRL-201-035                         n                    n
#
#                Metabolic_Disease Cardiovascular_Disease  comorbidities_total  \
# AIIDB0330                      y                      y                    6
# AIIDM0042                      y                      y                    3
# AIIDM0318                      n                      n                    0
# AIIDV1015                      y                      n                    2
# AIIDV1406                      y                      y                    8
# ...                          ...                    ...                  ...
# AIIDM0040                      n                      n                    0
# COVIRL-201-015                 n                      y                    3
# AIIDV1085                      y                      y                    5
# AIIDM0020                      y                      y                    4
# COVIRL-201-035                 n                      n                    0
#
#                 WHO_severity
# AIIDB0330                  3
# AIIDM0042                  2
# AIIDM0318                  3
# AIIDV1015                  1
# AIIDV1406                  1
# ...                      ...
# AIIDM0040                  2
# COVIRL-201-015             3
# AIIDV1085                  3
# AIIDM0020                  1
# COVIRL-201-035             3
#
# [82 rows x 17 columns]

# %% [markdown]
# ## Perform multi linear regression for each species

# %%
result = []
covariates = ['Age', 'BMI', 'Sex', 'comorbidities_total']
X = metadata_df[covariates]
for species in clr_data_df.columns:
    x = clr_data_df[species]
    y = metadata_df['WHO_severity']
    df = pd.concat([clr_data[species],X],axis=1)
    x = sm.add_constant(df)
    model = sm.OLS(y, x).fit()
    # p_values = model.summary2().tables[1]['P>|t|']
    result.append((species, model.pvalues[1]))

# %% [markdown]
# ## Correct for multiple testing using the Benjamini-Hochberg method

# %%
pvalues = [r[1] for r in result]
reject, p_values_fdr, _, _ = multipletests(pvalues, alpha=0.1, method='fdr_bh')

# extract the significant species
new_sig_species = [r[0] for i, r in enumerate(results) if p_values_fdr[i] <= 0.1]

# %% [markdown]
# ## Significant species

# %%
# Print significant species
print('Significant species after adjustment (FDR <= 0.1):', len(new_sig_species))
# Out:
# Significant species after adjustment (FDR <= 0.1): 84

# %%
[(r[0],r[1]) for i, r in enumerate(results) if p_values_fdr[i] <= 0.1]
# Out:
# [('Clostridium_sartagoforme', 0.001814317037460714),
#  ('Bacteroides_plebeius', 0.0025090452648332882),
#  ('Clostridium_methylpentosum', 0.0003101867914927888),
#  ('Escherichia.Shigella_flexneri', 0.030099378162692807),
#  ('Subdoligranulum_variabile', 0.011951201287901413),
#  ('Clostridium_disporicum', 0.0003706793559823975),
#  ('Finegoldia_magna', 0.0016203824930970496),
#  ('Bacteroides_acidifaciens', 0.00015912151855799437),
#  ('Atopobium_parvulum', 0.006632599675692202),
#  ('Streptococcus_suis', 0.04801078046036608),
#  ('Clostridium_scindens', 0.03257525239215355),
#  ('Blautia_schinkii', 0.007120391799397053),
#  ('Clostridium_aminobutyricum', 0.01050132855846613),
#  ('Enterococcus_mundtii', 0.011026385161287353),
#  ('Anaerostipes_butyraticus', 0.009269569552335741),
#  ('Acidaminococcus_intestini', 0.01645526176783011),
#  ('Lactobacillus_delbrueckii', 0.06355245971461616),
#  ('Methanobrevibacter_smithii', 4.0535270913807776e-05),
#  ('Eubacterium_siraeum', 0.01510024826869974),
#  ('Solobacterium_moorei', 0.0012923564702762627),
#  ('Anaerosporobacter_mobilis', 0.006673868521490599),
#  ('Blautia_stercoris', 0.008097619254980874),
#  ('Melissococcus_plutonius', 0.004987674030320956),
#  ('Streptococcus_thermophilus', 0.04583462894590098),
#  ('Clostridium_bifermentans', 0.012510784072456028),
#  ('Christensenella_minuta', 0.018671248607039042),
#  ('Streptococcus_sanguinis', 0.003845587774184804),
#  ('Actinomyces_graevenitzii', 0.012450229713108973),
#  ('Pseudoflavonifractor_capillosus', 0.0003001001665682188),
#  ('Coprobacillus_cateniformis', 0.012737847223253591),
#  ('Lactobacillus_fermentum', 0.009996763250810338),
#  ('Clostridium_viride', 0.015230815434657693),
#  ('Eubacterium_contortum', 2.7994060605946616e-05),
#  ('Actinomyces_odontolyticus', 0.013400331224940224),
#  ('Actinomyces_lingnae', 0.017010445309338155),
#  ('Clostridium_irregulare', 0.00019740717705326612),
#  ('Acetanaerobacterium_elongatum', 0.02305031605223211),
#  ('Clostridium_aldenense', 0.002359551727761985),
#  ('Blautia_luti', 0.009634288362630196),
#  ('Bacteroides_ovatus', 0.012889060601413887),
#  ('Anaerofilum_pentosovorans', 0.022425098370764823),
#  ('Clostridium_tertium', 0.014730763409839906),
#  ('Clostridium_lavalense', 0.0009915439981034169),
#  ('Blautia_hydrogenotrophica', 0.03436936632350486),
#  ('Clostridium_fusiformis', 0.03864702844017267),
#  ('Clostridium_cellulosi', 0.004879012477323349),
#  ('Bacteroides_nordii', 0.020229692469636084),
#  ('Lactobacillus_paracasei', 0.039669798064837565),
#  ('Actinomyces_naeslundii', 0.0002584821618147399),
#  ('Clostridium_oroticum', 0.0042111559455797025),
#  ('Eubacterium_oxidoreducens', 0.02065299411695143),
#  ('Anaerorhabdus_furcosa', 0.00016510337966346174),
#  ('Clostridium_leptum', 0.0073407229626938405),
#  ('Holdemania_filiformis', 0.011618102469843839),
#  ('Alistipes_finegoldii', 0.001266636717745596),
#  ('Hydrogenoanaerobacterium_saccharovorans', 0.006997545702331115),
#  ('Clostridium_innocuum', 1.4002637227923701e-05),
#  ('Blautia_wexlerae', 0.021817423755102254),
#  ('Acetivibrio_ethanolgignens', 0.002614948222464524),
#  ('Eubacterium_ventriosum', 0.010761650764491596),
#  ('Enterococcus_asini', 0.008943950111934594),
#  ('Clostridium_thermocellum', 0.01346394104182221),
#  ('Clostridium_hathewayi', 0.0006946725441064212),
#  ('Clostridium_citroniae', 0.0023061237381931106),
#  ('Lactonifactor_longoviformis', 0.004748362814726725),
#  ('Dialister_invisus', 0.000995954823118133),
#  ('Hespellia_porcina', 0.00026608413331911327),
#  ('Ruminococcus_obeum', 0.013677179815559923),
#  ('Actinomyces_massiliensis', 0.010902370037146617),
#  ('Marvinbryantia_formatexigens', 0.007226605320160721),
#  ('Clostridium_clostridioforme', 3.732316184359633e-05),
#  ('Ruminococcus_lactaris', 0.0016449998778516079),
#  ('Clostridium_asparagiforme', 0.01874242984157092),
#  ('Enterococcus_faecalis', 0.006277110336891976),
#  ('Eggerthella_lenta', 0.0003415493315232234),
#  ('Clostridium_hiranonis', 0.0036693451210623347),
#  ('Anaerofustis_stercorihominis', 0.01773775608168543),
#  ('Oribacterium_sinus', 0.01433769228153853),
#  ('Clostridium_sporosphaeroides', 0.002894993252377775),
#  ('Eubacterium_coprostanoligenes', 0.023956254091312395),
#  ('Butyrivibrio_fibrisolvens', 0.0031697676407803177),
#  ('Natranaerovirga_pectinivora', 0.008283618269044979),
#  ('Robinsoniella_peoriensis', 0.0026494680183904076),
#  ('Enterococcus_casseliflavus', 0.004721914831589958)]

# %%
new_sig_species
# Out:
# ['Clostridium_sartagoforme',
#  'Bacteroides_plebeius',
#  'Clostridium_methylpentosum',
#  'Escherichia.Shigella_flexneri',
#  'Subdoligranulum_variabile',
#  'Clostridium_disporicum',
#  'Finegoldia_magna',
#  'Bacteroides_acidifaciens',
#  'Atopobium_parvulum',
#  'Streptococcus_suis',
#  'Clostridium_scindens',
#  'Blautia_schinkii',
#  'Clostridium_aminobutyricum',
#  'Enterococcus_mundtii',
#  'Anaerostipes_butyraticus',
#  'Acidaminococcus_intestini',
#  'Lactobacillus_delbrueckii',
#  'Methanobrevibacter_smithii',
#  'Eubacterium_siraeum',
#  'Solobacterium_moorei',
#  'Anaerosporobacter_mobilis',
#  'Blautia_stercoris',
#  'Melissococcus_plutonius',
#  'Streptococcus_thermophilus',
#  'Clostridium_bifermentans',
#  'Christensenella_minuta',
#  'Streptococcus_sanguinis',
#  'Actinomyces_graevenitzii',
#  'Pseudoflavonifractor_capillosus',
#  'Coprobacillus_cateniformis',
#  'Lactobacillus_fermentum',
#  'Clostridium_viride',
#  'Eubacterium_contortum',
#  'Actinomyces_odontolyticus',
#  'Actinomyces_lingnae',
#  'Clostridium_irregulare',
#  'Acetanaerobacterium_elongatum',
#  'Clostridium_aldenense',
#  'Blautia_luti',
#  'Bacteroides_ovatus',
#  'Anaerofilum_pentosovorans',
#  'Clostridium_tertium',
#  'Clostridium_lavalense',
#  'Blautia_hydrogenotrophica',
#  'Clostridium_fusiformis',
#  'Clostridium_cellulosi',
#  'Bacteroides_nordii',
#  'Lactobacillus_paracasei',
#  'Actinomyces_naeslundii',
#  'Clostridium_oroticum',
#  'Eubacterium_oxidoreducens',
#  'Anaerorhabdus_furcosa',
#  'Clostridium_leptum',
#  'Holdemania_filiformis',
#  'Alistipes_finegoldii',
#  'Hydrogenoanaerobacterium_saccharovorans',
#  'Clostridium_innocuum',
#  'Blautia_wexlerae',
#  'Acetivibrio_ethanolgignens',
#  'Eubacterium_ventriosum',
#  'Enterococcus_asini',
#  'Clostridium_thermocellum',
#  'Clostridium_hathewayi',
#  'Clostridium_citroniae',
#  'Lactonifactor_longoviformis',
#  'Dialister_invisus',
#  'Hespellia_porcina',
#  'Ruminococcus_obeum',
#  'Actinomyces_massiliensis',
#  'Marvinbryantia_formatexigens',
#  'Clostridium_clostridioforme',
#  'Ruminococcus_lactaris',
#  'Clostridium_asparagiforme',
#  'Enterococcus_faecalis',
#  'Eggerthella_lenta',
#  'Clostridium_hiranonis',
#  'Anaerofustis_stercorihominis',
#  'Oribacterium_sinus',
#  'Clostridium_sporosphaeroides',
#  'Eubacterium_coprostanoligenes',
#  'Butyrivibrio_fibrisolvens',
#  'Natranaerovirga_pectinivora',
#  'Robinsoniella_peoriensis',
#  'Enterococcus_casseliflavus']
